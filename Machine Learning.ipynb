# %% [markdown]
# ## Machine Learning

# %% [markdown]
# * Regression
# * Classification
# * Desnsity Estimation

# %% [markdown]
# ### ML Algorithms

# %% [markdown]
# * Regression
# * Clustering
# * Dimension Reduction
# * Association Rules
# * Deep Learning
# * Instance - based
# * Desicion trees
# * Bayesian
# * Ensemble
# * Regularization

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Grouping by usecases

# %% [markdown]
# ![image.png](attachment:image.png)
