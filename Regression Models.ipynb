# %% [markdown]
# * Simple Linear Regression
# * Multiple Linear Regression

# %% [markdown]
# ### Assumptions

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Simple Linear Regression

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

import sklearn

from pylab import rcParams
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 10 , 8

# %%
rooms =  2 * np.random.rand(100 , 1) + 3
rooms[1:10]
# Out:
# array([[3.83078221],
#        [4.89447107],
#        [4.80357652],
#        [3.51351973],
#        [4.8984868 ],
#        [4.00816511],
#        [3.61758589],
#        [4.35567538],
#        [3.99596838]])

# %%
price = 265 + 6 * rooms + abs(np.random.randn(100 , 1))
price[1:10]
# Out:
# array([[288.09491483],
#        [295.08005137],
#        [295.20665509],
#        [286.5185724 ],
#        [295.62025453],
#        [289.70019733],
#        [288.46856953],
#        [291.29718793],
#        [291.1227555 ]])

# %%
plt.plot(rooms , price , 'r^')   # r = red , ^ = marker
plt.show()

# %%
x = rooms
y = price

linreg  = LinearRegression()
linreg.fit(x , y)

print(linreg.intercept_ , linreg.coef_)
# Out:
# [266.3998803] [[5.85533627]]

# %%
print(linreg.score(x , y))
# Out:
# 0.9772765947820771
